# %% [markdown]
# **Task 1:**
#
# **Problem Statement**
#
# Write code to position 5 equal-sized (50 X 50px) boxes A, B, C, D, and E as follows,
#  1.  box A 200px from the left, and 200px from the top of the viewport.
#  2.  box B -30px left, and -30px above from the center of box A.
#  3.  box B -30px right, and -30px above from the center of box A.
#  4.  box B -30px left, and -30px below from the center of box A.
#  5.  box B -30px right, and -30px below from the center of box A.
#
#
#  ```
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <meta charset="UTF-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#     <title>Task1</title>
#     <style>
#       .box {
#         width: 50px;
#         height: 50px;
#         background-color: rgb(0, 246, 205);
#         border: 1.5px solid yellow;
#         text-align: center;
#         position: absolute;
#       }
#       .A {
#         left: 200px;
#         top: 200px;
#       }
#       .B {
#         left: 170px;
#         top: 170px;
#       }
#       .C {
#         left: 230px;
#         top: 170px;
#       }
#       .D {
#         top: 230px;
#         left: 170px;
#       }
#       .E {
#         top: 230px;
#         left: 230px;
#       }
#     </style>
#   </head>
#   <body>
#     <div class="box A">A</div>
#     <div class="box B">B</div>
#     <div class="box C">C</div>
#     <div class="box D">D</div>
#     <div class="box E">E</div>
#   </body>
# </html>
#
#
#  ```
#
#  **Output:**
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Task 2:**
#
#  **Problem Statement**
#
# Explain the difference between Absolute and Relative positioning.
#
# **Relative:**
#
#  * With relative positioning, an
# element can be moved up,
# down, left, or right from its
# normal position.
#
#  * It will not break the normal
# document flow to position
# the element on the page.
#
#  *  The element will leave the
# space at its original position
# & other content will not be
# adjusted to fit into any gap
# left by the element
#
# **Absolute:**
#
#  * With absolute positioning, an
# element is positioned relative
# to its nearest positioned
# ancestor.
#
#  *  It will break the normal
# document flow to position
# the element on the page.
#
#  *  The element will not leave
# any space in its original
# position.

# %% [markdown]
# **Task3:**
#
#
# **Problem Statement**
#
# Create a card as shown in the picture below. (You can use CSS float property only for layout).
#
#
# ```
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <meta charset="UTF-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#     <title>Document</title>
#     <style>
#       .card {
#         height: 250px;
#         width: 50%;
#         background-color: beige;
#         border: 3px solid black;
#         padding: 10px;
#       }
#      .card img {
#         float: right;
#         width: 220px;
#         height: 180px;
#         padding-right: 20px;
#         padding-top: 20px;
#       }
#
#       h1,
#       p {
#         padding-left: 15px;
#       }
#     </style>
#   </head>
#   <body>
#     <div class="card">
#       <img src="earth.png" alt="" />
#       <h1>The Earth!!!</h1>
#       <p>
#         Nature is Earth's masterpiece, a symphony of life composed through
#         millennia. Its landscapes whisper tales of ancient mountains, winding
#         rivers, and flourishing forests, reminding us of the planet's boundless
#         beauty. From delicate petals to towering redwoods, nature's artistry
#         stirs awe and reconnects us to the essence of existence. Nature is
#         Earth's masterpiece, a symphony of life composed through millennia. Its
#         landscapes whisper tales of ancient mountains, winding rivers, and
#         flourishing forests.
#       </p>
#     </div>
#   </body>
# </html>
#
#
# ```
#
#
# **Output:**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Task 4:**
#
# **Problem Statement**
#
# Create a simple header that sticks to the top of a webpage upon scrolling.
#
# ```
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <meta charset="UTF-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#     <title>Document</title>
#     <style>
#       * {
#         margin: 0;
#       }
#       .navbar {
#         width: 100%;
#         background-color: black;
#         position: fixed;
#         color: white;
#         display: flex;
#         justify-content: space-between;
#         align-items: center;
#         padding: 20px;
#         font-size: 18px;
#       }
#
#       .links a {
#         text-decoration: none;
#         padding: 10px;
#         margin-right: 40px;
#
#         color: white;
#         font-family: "poppins", sans-serif;
#       }
#       .start {
#         border: 2px solid yellow;
#         border-radius: 17px;
#       }
#     </style>
#   </head>
#   <body>
#     <nav class="navbar">
#       LOGO
#       <nav class="links">
#         <a href="#">Home</a>
#         <a href="#">Pricing</a>
#         <a href="#">Contact</a>
#         <a href="#">Terms and Conditions</a>
#         <a class="start" href="#">Get Started</a>
#       </nav>
#     </nav>
#
#     <main>
#       <h2>Heading1</h2>
#       <p>
#         Lorem ipsum dolor sit, amet consectetur adipisicing elit. Suscipit culpa
#         quasi reiciendis perferendis enim voluptate corrupti ea saepe
#         praesentium, voluptatum voluptatibus odit. Dolorem voluptates
#         voluptatibus cumque praesentium doloremque eius nihil, soluta nemo
#         tenetur ducimus enim illum officia temporibus ab possimus eveniet vitae
#         illo. Blanditiis expedita delectus repudiandae necessitatibus eligendi
#         non maxime fugit.
#       </p>
#       <h2>Heading2</h2>
#       <p>
#         Lorem ipsum dolor, sit amet consectetur adipisicing elit. Pariatur neque
#         tempore alias suscipit, consequuntur impedit illo quia corporis
#         corrupti, id error quibusdam velit, quo voluptas deserunt! Quos, rerum
#         quibusdam quia modi laudantium cum sit expedita autem consectetur,
#         accusantium perspiciatis non? Tempore iure asperiores in delectus quis
#         iusto autem. Excepturi, quas?
#       </p>
#       <h2>Heading3</h2>
#       <p>
#         Lorem ipsum dolor sit amet consectetur adipisicing elit. Maiores
#         quisquam velit rerum? Eveniet repellendus quas aliquid blanditiis dolore
#         nostrum voluptatem cumque ipsum aspernatur, dicta exercitationem non
#         totam sed architecto soluta temporibus, culpa molestias. Quidem maxime
#         suscipit libero vitae quisquam natus officia fugit ad, provident sequi,
#         error nam eos, accusantium nesciunt.
#       </p>
#     </main>
#   </body>
# </html>
#
#
# ```
#
#
# **Output:**
#
# ![{4D7C9B7E-3E1E-42C1-B56B-EFF84FCF1464}.png](data:image/png;base64,...)

# %% [markdown]
# **Task 5:**
#
#  **Problem Statement**
#
#  Explain the z-index, with a code example.
#
#
#  **CSS z-index**
#
#  The z-index CSS property arranges the z-position of a positioned element, as well as its descendants.
#  The z-index property takes an integer value, which represents the element's position on the z-axis.  Elements
# with higher z-index values are placed on top of elements with lower z-index values.
#  By default, elements have a z-index value of 0, which means their stacking order is determined by their position
# in the HTML document and their parent's stacking order.
#
#
# **example:**
#
# ```
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <meta charset="UTF-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#     <title>Document</title>
#     <style>
#       div {
#         width: 300px;
#         height: 300px;
#       }
#       div > img {
#         width: 100%;
#         height: 100%;
#       }
#
#       .first {
#         position: relative;
#       }
#
#       .second {
#         position: relative;
#         left: 50px;
#         top: -50px;
#         z-index: -1;
#       }
#
#       .third {
#         position: relative;
#         left: 100px;
#         top: -100px;
#         z-index: -2;
#       }
#     </style>
#   </head>
#   <body>
#     <div class="first">
#       <img
#         src="https://www.springboard.com/blog/wp-content/uploads/2022/06/what-does-a-coder-do-2022-career-guide-1.jpg"
#         alt=""
#       />
#     </div>
#
#     <div class="second">
#       <img
#         src="https://easy-peasy.ai/cdn-cgi/image/quality=80,format=auto,width=700/https://media.easy-peasy.ai/2d20b705-9dac-4f1d-9a01-54ea7557aa4f/6c413449-da83-4063-a7b8-b7bfbb902612.png"
#         alt=""
#       />
#     </div>
#
#     <div class="third">
#       <img
#         src="https://images.stockcake.com/public/5/e/6/5e6fb906-70e0-4ec9-9df9-fb564a8fec74_large/coder-at-work-stockcake.jpg"
#         alt=""
#       />
#       />
#     </div>
#   </body>
# </html>
#
#
# ```
#
#
#
# **Output:**
#
#
# ![{8BC9FDDC-E0B6-4847-8E09-5442E296A31E}.png](data:image/png;base64,...)

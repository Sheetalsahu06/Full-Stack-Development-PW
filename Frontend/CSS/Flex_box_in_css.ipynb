# %% [markdown]
# **1. Describe the main differences between the CSS Flexbox layout model and the CSS Grid layout model. When would you choose to use one over the other?**
#
# #CSS Flexbox#
#
# Flexbox, or the Flexible Box Layout, is a one-dimensional layout model in CSS. It is used to arrange items in a single direction, either as a row or a column. Flexbox is content-driven, which means the layout adjusts based on the size and number of items within the container. It provides powerful tools for alignment, spacing, and ordering of items, making it ideal for creating responsive elements like navigation bars, buttons, or lists. Flexbox is best used when the layout needs to be flexible in one direction only, and it helps reduce the need for floats and manual positioning.
#
#
# **Use Flexbox when:**
#
# * You have a linear layout (e.g., navigation bars, toolbars, lists).
# * Items should wrap or stretch depending on screen size.
# * You need simple alignment and distribution of space.
# * The layout is content-driven and doesn’t need a strict grid structure.
#
# **Example use cases:**
#
# * Horizontal nav menu
# * Centering a button within a container
# * Aligning form elements in a row
#
# #CSS Grid#
#
# CSS Grid is a two-dimensional layout system that allows developers to design web layouts using both rows and columns. It is layout-driven, which means you define the structure first—by creating a grid of cells—and then place items within those cells. Grid is especially useful for complex and consistent layouts, like web pages with headers, sidebars, main content, and footers. It provides precise control over element positioning and supports overlapping elements and grid gaps. CSS Grid is ideal when you need to build structured, grid-based layouts across two axes.
#
#
#
# **Use Grid when:**
#
# * You’re creating entire page layouts or components with rows and columns.
# * You want precise control over both dimensions of the layout.
# * The layout structure is more complex or consistent (e.g., templates).
# * You need overlapping elements or layering within a grid.
#
# **Example use cases:**
#
# * Website layout with header, sidebar, main, and footer
# * Image galleries
# * Dashboard interfaces

# %% [markdown]
# **2. Explain the role of the following key properties in the Flexbox layout mode**
#  1. justify-content
#  2. align-items
#  3. gap
#  4. flex-direction
#  5. flex-wrap
#
#
# **Justify Content**
# * Aligns the entire flex container's items along the main axis.
# * Possible values: flex-start, flex-end, center, space-between, space-around,  space-evenly.
# * Determines how space is distributed around items.
#
#  **Align Item**
#
# * Aligns flex items along the cross-axis.
# * Possible values: stretch, center, flex-start, flex-end.
# * The default value is stretch.
#
# **Gap**
#
# * Sets the spacing between items in a flex container.
# * Can be defined for rows (row-gap) and columns (column-gap), or both (gap).
# * Useful for creating consistent spacing without margins.
#
#
# **Flex Direction**
# * Specifies the direction of the flex items in the flex container.
# * Possible values: row, row-reverse, column, column-reverse.
# * Determines the main axis direction (horizontal or vertical).
#
# **Flex Wrap**
# * Controls whether flex items are forced into a single line or can wrap onto multiple lines.
# * Possible values: nowrap, wrap, wrap-reverse.
# * The default value is nowrap.

# %% [markdown]
# **3.  Write the code to center a div using CSS Flexbox.**
#
# ```
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <meta charset="UTF-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#     <title>Document</title>
#     <style>
#       body {
#         display: flex;
#         justify-content: center;
#       }
#       div {
#         width: 300px;
#         height: 300px;
#         background-color: greenyellow;
#         text-align: center;
#       }
#     </style>
#   </head>
#   <body>
#     <div></div>
#   </body>
# </html>
#
# ```
#
#
# **Output:**
#
#
# ![{7BF98A48-9C0F-4061-AB97-E0754E7449C1}.png](data:image/png;base64,...)

# %% [markdown]
# **4. A client of yours wants to add a pricing section on their website to showcase their newly introduced premium plans.**
#
#
# ```
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <meta charset="UTF-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#     <title>Pricing Card</title>
#     <link rel="stylesheet" href="style.css" />
#   </head>
#   <body>
#     <div class="container">
#       <div class="plan-box">
#         <h1>Free Plan</h1>
#         <p class="plan-title">For personal</p>
#         <h2 class="price">$0</h2>
#         <ul class="plan-list">
#           <li>1 uders</li>
#           <li>4 Web mails</li>
#           <li>Responsive Website</li>
#           <li>Free SSL</li>
#         </ul>
#         <div class="button">
#           <button class="subscribe-btn">Suscribe now</button>
#         </div>
#       </div>
#       <div class="plan-box1">
#         <h1>Basic Plan</h1>
#         <p class="plan-title">For small business</p>
#         <h2 class="price">$29</h2>
#         <ul class="plan-list1">
#           <li>4 uders</li>
#           <li>10 Web mails</li>
#           <li>Responsive Website</li>
#           <li>Free SSL</li>
#         </ul>
#         <div class="button">
#           <button class="subscribe-btn1">Suscribe now</button>
#         </div>
#       </div>
#       <div class="plan-box">
#         <h1>Pro Plan</h1>
#         <p class="plan-title">For enterprise</p>
#         <h2 class="price">$49</h2>
#         <ul class="plan-list">
#           <li>Unlimited uders</li>
#           <li>Unlimited Web mails</li>
#           <li>Responsive Website</li>
#           <li>Free SSL + SEO</li>
#         </ul>
#         <div class="button">
#           <button class="subscribe-btn">Suscribe now</button>
#         </div>
#       </div>
#     </div>
#   </body>
# </html>
#
# ```
# `style.css`
#
# ```
# body {
#   font-family: "Poppins", sans-serif;
#   text-transform: capitalize;
# }
#
# .container {
#   display: flex;
#   justify-content: center;
#   align-items: center;
#   gap: 2rem;
# }
# .plan-box {
#   width: 250px;
#   box-shadow: 0 0 3px rgb(0, 0, 5);
#   border-radius: 12px;
#   padding: 30px;
#   font-size: 1rem;
#   box-sizing: border-box;
# }
# .plan-box1 {
#   width: 250px;
#   color: white;
#   background-color: #010545;
#   box-shadow: 0 0 3px rgb(0, 0, 5);
#   border-radius: 12px;
#   padding: 30px;
#   font-size: 1rem;
#   box-sizing: border-box;
# }
#
# .plan-title {
#   margin-top: -20px;
#   font-size: 1rem;
# }
# .price {
#   font-size: 1.5rem;
#   font-weight: bold;
#   margin-top: 8px;
# }
#
# .plan-list {
#   list-style-type: none;
#   padding: 0;
#   margin: 0;
# }
# .plan-list1 {
#   list-style-type: none;
#   padding: 0;
#   margin: 0;
# }
# .plan-list li {
#   margin: 20px 0;
#   font-size: 1rem;
#   padding-left: 30px;
#   position: relative;
# }
# .plan-list1 li {
#   margin: 20px 0;
#   font-size: 1rem;
#   padding-left: 30px;
#   position: relative;
# }
# .plan-list li::before {
#   content: "✔";
#   color: #010545;
#   font-weight: bold;
#   position: absolute;
#   top: 0;
#   left: 0;
# }
# .plan-list1 li::before {
#   content: "✔";
#   color: white;
#   font-weight: bold;
#   position: absolute;
#   top: 0;
#   left: 0;
# }
#
#
# .subscribe-btn {
#   color: white;
#   padding: 10px 30px;
#   background-color: #010545;
#   border-radius: 20px;
#   margin-top: 20px;
#   font-size: 1rem;
# }
# .subscribe-btn1 {
#   color: #010545;
#   padding: 10px 30px;
#   background-color: white;
#   border-radius: 20px;
#   margin-top: 20px;
#   font-size: 1rem;
# }
#
#
# .button {
#   display: flex;
#   justify-content: center;
#   align-items: center;
# }
#
# ```
#
#
# **Output:**
#
# ![{734C6004-598C-4BB7-A15D-2FF046F56F14}.png](data:image/png;base64,...)

# %% [markdown]
# **5. build a clone of the IRCTC Ticket booking page.**
#
#
# ```
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <meta charset="UTF-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#     <title>IRCTC clone</title>
#     <link rel="stylesheet" href="styles.css" />
#   </head>
#   <body>
#     <div class="main1">
#       <div class="left">
#         <header class="main-header">
#           <div class="logo">
#             <img
#               src="https://upload.wikimedia.org/wikipedia/en/thumb/4/45/IRCTC_Logo.svg/1200px-IRCTC_Logo.svg.png"
#               alt=""
#             />
#             <img
#               src="https://5.imimg.com/data5/SELLER/Default/2021/2/GI/JR/US/4184318/irctc-agentship-provider-500x500.png"
#               alt=""
#             />
#           </div>
#           <div class="nav">
#             <nav class="nav-links">
#               <a href="#" class="ask">ask disha</a>
#               <a href="#">contact</a>
#               <a href="#">alerts</a>
#             </nav>
#             <nav class="btns">
#               <button class="btn login">Login</button>
#               <button class="btn register">Register</button>
#               <button class="btn agent-login">Agent Login</button>
#             </nav>
#           </div>
#         </header>
#         <div class="booking-sec">
#           <h1>Indian Railways</h1>
#           <p>
#             <span class="green">Safety</span>
#             <span class="orange">Security</span>
#             <span class="blue">Punctuality</span>
#           </p>
#
#           <div class="actions">
#             <button class="action-btn">BOOK Ticket</button>
#             <button class="action-btn">PNR Status</button>
#             <button class="action-btn">Charts / Vacancy</button>
#           </div>
#
#           <div class="form-box">
#             <div class="form-row">
#               <div>
#                 From<br /><strong>Bangalore</strong><br /><small
#                   >KSR - Bangalore</small
#                 >
#               </div>
#               <div class="exchange">⇄</div>
#               <div>
#                 To<br /><strong>Kasaragod</strong><br /><small
#                   >KSD - Kasaragod</small
#                 >
#               </div>
#             </div>
#             <div class="form-row">
#               <div>
#                 Date<br /><strong>01 Aug 23</strong><br /><small>Tuesday</small>
#               </div>
#               <div>
#                 Class<br /><strong>3A</strong><br /><small>AC 3 tier</small>
#               </div>
#               <div>
#                 Seat Type<br /><strong>TATKAL</strong><br /><small
#                   >AC 3 Tier</small
#                 >
#               </div>
#             </div>
#             <button class="search-btn">Search Train →</button>
#           </div>
#         </div>
#       </div>
#       <!-- Main Booking Section -->
#
#       <div class="right">
#         <img src="vande bharat.png" alt="Train 1" class="top-img" />
#       </div>
#     </div>
#   </body>
# </html>
#
# ```
#
#
# **Output:**
#
#
# ![{678CCBD5-A9C9-4038-BE40-5D66306A00FA}.png](data:image/png;base64,...)
